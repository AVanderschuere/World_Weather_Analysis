# %%
# Import the dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random lat and long combos

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Import the requests library.
import requests
# Import the time library.
import time
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# # Create an empty list to hold the weather data.
# city_data = []
# # Print the beginning of the logging.
# print("Beginning Data Retrieval     ")
# print("-----------------------------")

# # Create counters.
# record_count = 1
# set_count = 1

# # Loop through all the cities in the list.
# for i, city in enumerate(cities):

#     # Group cities in sets of 50 for logging purposes.
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#         time.sleep(60)

#     # Create endpoint URL with each city.
#     city_url = url + "&q=" + city.replace(" ","+")

#     # Log the URL, record, and set numbers and the city.
#     print(f"Processing Record {record_count} of Set {set_count} | {city}")
#     # Add 1 to the record count.
#     record_count += 1

#     # Run an API request for each of the cities.
#     try:
#         # Parse the JSON and retrieve data.
#         city_weather = requests.get(city_url).json()
#         # Parse out the needed data.
#         city_lat = city_weather["coord"]["lat"]
#         city_lng = city_weather["coord"]["lon"]
#         city_max_temp = city_weather["main"]["temp_max"]
#         city_humidity = city_weather["main"]["humidity"]
#         city_clouds = city_weather["clouds"]["all"]
#         city_wind = city_weather["wind"]["speed"]
#         city_country = city_weather["sys"]["country"]
#         city_weather_description = city_weather["weather"][0]["description"]
     
#         # Append the city information into city_data list.
#         city_data.append({"City": city.title(),
#                           "Lat": city_lat,
#                           "Lng": city_lng,
#                           "Max Temp": city_max_temp,
#                           "Current Description": city_weather_description,
#                           "Humidity": city_humidity,
#                           "Cloudiness": city_clouds,
#                           "Wind Speed": city_wind,
#                           "Country": city_country})

# # If an error is experienced, skip the city.
#     except:
#         print("City not found. Skipping...")
#         pass

# # Indicate that Data Loading is complete.
# print("-----------------------------")
# print("Data Retrieval Complete      ")
# print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | victoria
# Processing Record 2 of Set 1 | vestmannaeyjar
# Processing Record 3 of Set 1 | deogarh
# Processing Record 4 of Set 1 | leh
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | coihaique
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | lompoc
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | solano
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | urucui
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | kaeo
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | rio gallegos
# Processing Record 24 of Set 1 | mikkeli
# Processing Record 25 of Set 1 | andover
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | codrington
# Processing Record 28 of Set 1 | loralai
# Processing Record 29 of Set 1 | chokurdakh
# Processing Record 30 of Set 1 | torbay
# Processing Record 31 of Set 1 | tondano
# Processing Record 32 of Set 1 | kavieng
# Processing Record 33 of Set 1 | semey
# Processing Record 34 of Set 1 | narsaq
# Processing Record 35 of Set 1 | muros
# Processing Record 36 of Set 1 | khatanga
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | melilla
# Processing Record 39 of Set 1 | adrar
# Processing Record 40 of Set 1 | havoysund
# Processing Record 41 of Set 1 | amahai
# Processing Record 42 of Set 1 | nantucket
# Processing Record 43 of Set 1 | marsh harbour
# Processing Record 44 of Set 1 | brae
# Processing Record 45 of Set 1 | delicias
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | annau
# Processing Record 48 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 1 | yukhnov
# Processing Record 1 of Set 2 | bontang
# Processing Record 2 of Set 2 | letpadan
# Processing Record 3 of Set 2 | lagoa
# Processing Record 4 of Set 2 | thompson
# Processing Record 5 of Set 2 | najran
# Processing Record 6 of Set 2 | saint-michel-des-saints
# Processing Record 7 of Set 2 | nikolskoye
# Processing Record 8 of Set 2 | rikitea
# Processing Record 9 of Set 2 | carnarvon
# Processing Record 10 of Set 2 | nome
# Processing Record 11 of Set 2 | esperance
# Processing Record 12 of Set 2 | airai
# Processing Record 13 of Set 2 | grand forks
# Processing Record 14 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 2 | iquique
# Processing Record 16 of Set 2 | katsuura
# Processing Record 17 of Set 2 | sur
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | chuy
# Processing Record 20 of Set 2 | kautokeino
# Processing Record 21 of Set 2 | skala
# Processing Record 22 of Set 2 | annaberg-buchholz
# Processing Record 23 of Set 2 | skjervoy
# Processing Record 24 of Set 2 | saskylakh
# Processing Record 25 of Set 2 | hobart
# Processing Record 26 of Set 2 | kota
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | busselton
# Processing Record 29 of Set 2 | arraial do cabo
# Processing Record 30 of Set 2 | saint-philippe
# Processing Record 31 of Set 2 | kahului
# Processing Record 32 of Set 2 | hithadhoo
# Processing Record 33 of Set 2 | trincomalee
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | mattru
# Processing Record 36 of Set 2 | norman wells
# Processing Record 37 of Set 2 | bluff
# Processing Record 38 of Set 2 | bambanglipuro
# Processing Record 39 of Set 2 | dikson
# Processing Record 40 of Set 2 | nichinan
# Processing Record 41 of Set 2 | atuona
# Processing Record 42 of Set 2 | wamba
# Processing Record 43 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 2 | pevek
# Processing Record 45 of Set 2 | cidreira
# Processing Record 46 of Set 2 | dakar
# Processing Record 47 of Set 2 | cuenca
# Processing Record 48 of Set 2 | bredasdorp
# Processing Record 49 of Set 2 | broken hill
# Processing Record 50 of Set 2 | vaini
# Processing Record 1 of Set 3 | puerto ayora
# Processing Record 2 of Set 3 | kirakira
# Processing Record 3 of Set 3 | tuburan
# Processing Record 4 of Set 3 | kirillov
# Processing Record 5 of Set 3 | saint-pierre
# Processing Record 6 of Set 3 | harindanga
# Processing Record 7 of Set 3 | georgetown
# Processing Record 8 of Set 3 | oistins
# Processing Record 9 of Set 3 | avera
# Processing Record 10 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 3 | lithakia
# Processing Record 12 of Set 3 | finschhafen
# Processing Record 13 of Set 3 | raha
# Processing Record 14 of Set 3 | rovaniemi
# Processing Record 15 of Set 3 | constitucion
# Processing Record 16 of Set 3 | cherskiy
# Processing Record 17 of Set 3 | rawson
# Processing Record 18 of Set 3 | lima
# Processing Record 19 of Set 3 | salvador
# Processing Record 20 of Set 3 | leningradskiy
# Processing Record 21 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 3 | lebu
# Processing Record 23 of Set 3 | port macquarie
# Processing Record 24 of Set 3 | tsogni
# Processing Record 25 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 3 | camana
# Processing Record 27 of Set 3 | bukama
# Processing Record 28 of Set 3 | walvis bay
# Processing Record 29 of Set 3 | kruisfontein
# Processing Record 30 of Set 3 | girne
# Processing Record 31 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 3 | nabire
# Processing Record 33 of Set 3 | russell
# Processing Record 34 of Set 3 | alofi
# Processing Record 35 of Set 3 | bethel
# Processing Record 36 of Set 3 | kushmurun
# Processing Record 37 of Set 3 | grindavik
# Processing Record 38 of Set 3 | tuktoyaktuk
# Processing Record 39 of Set 3 | cao bang
# Processing Record 40 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 3 | camacha
# Processing Record 42 of Set 3 | half moon bay
# Processing Record 43 of Set 3 | alice springs
# Processing Record 44 of Set 3 | nuuk
# Processing Record 45 of Set 3 | kloulklubed
# Processing Record 46 of Set 3 | ilulissat
# Processing Record 47 of Set 3 | tambun
# Processing Record 48 of Set 3 | surok
# Processing Record 49 of Set 3 | harper
# Processing Record 50 of Set 3 | margherita
# Processing Record 1 of Set 4 | ilebo
# Processing Record 2 of Set 4 | butaritari
# Processing Record 3 of Set 4 | severo-kurilsk
# Processing Record 4 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 4 | nenjiang
# Processing Record 6 of Set 4 | longyearbyen
# Processing Record 7 of Set 4 | tarkwa
# Processing Record 8 of Set 4 | mackay
# Processing Record 9 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 4 | ligaya
# Processing Record 11 of Set 4 | kavaratti
# Processing Record 12 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 4 | lucapa
# Processing Record 14 of Set 4 | takoradi
# Processing Record 15 of Set 4 | honiara
# Processing Record 16 of Set 4 | meulaboh
# Processing Record 17 of Set 4 | awjilah
# Processing Record 18 of Set 4 | maholi
# Processing Record 19 of Set 4 | awbari
# Processing Record 20 of Set 4 | bengkulu
# Processing Record 21 of Set 4 | jinchang
# Processing Record 22 of Set 4 | jalu
# Processing Record 23 of Set 4 | dorado
# Processing Record 24 of Set 4 | kandrian
# Processing Record 25 of Set 4 | konya
# Processing Record 26 of Set 4 | nioro
# Processing Record 27 of Set 4 | puerto narino
# Processing Record 28 of Set 4 | sao lourenco
# Processing Record 29 of Set 4 | berehove
# Processing Record 30 of Set 4 | hamilton
# Processing Record 31 of Set 4 | vredendal
# Processing Record 32 of Set 4 | tasiilaq
# Processing Record 33 of Set 4 | venado tuerto
# Processing Record 34 of Set 4 | jumla
# Processing Record 35 of Set 4 | mae hong son
# Processing Record 36 of Set 4 | abu kamal
# Processing Record 37 of Set 4 | maceio
# Processing Record 38 of Set 4 | vardo
# Processing Record 39 of Set 4 | faanui
# Processing Record 40 of Set 4 | baleshwar
# Processing Record 41 of Set 4 | hasaki
# Processing Record 42 of Set 4 | moscow
# Processing Record 43 of Set 4 | taltal
# Processing Record 44 of Set 4 | kapaa
# Processing Record 45 of Set 4 | port elizabeth
# Processing Record 46 of Set 4 | tacoronte
# Processing Record 47 of Set 4 | bubaque
# Processing Record 48 of Set 4 | sayyan
# Processing Record 49 of Set 4 | pisco
# Processing Record 50 of Set 4 | balabagan
# Processing Record 1 of Set 5 | sao filipe
# Processing Record 2 of Set 5 | wassenberg
# Processing Record 3 of Set 5 | chimbote
# Processing Record 4 of Set 5 | santa helena de goias
# Processing Record 5 of Set 5 | buluang
# Processing Record 6 of Set 5 | berlevag
# Processing Record 7 of Set 5 | mnogovershinnyy
# Processing Record 8 of Set 5 | gorontalo
# Processing Record 9 of Set 5 | bandarbeyla
# Processing Record 10 of Set 5 | beringovskiy
# Processing Record 11 of Set 5 | husavik
# Processing Record 12 of Set 5 | port maria
# Processing Record 13 of Set 5 | canyon
# Processing Record 14 of Set 5 | hobyo
# Processing Record 15 of Set 5 | hornepayne
# Processing Record 16 of Set 5 | waregem
# Processing Record 17 of Set 5 | derzhavinsk
# Processing Record 18 of Set 5 | sawakin
# Processing Record 19 of Set 5 | gat
# Processing Record 20 of Set 5 | hambantota
# Processing Record 21 of Set 5 | luderitz
# Processing Record 22 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 23 of Set 5 | nanortalik
# Processing Record 24 of Set 5 | oswego
# Processing Record 25 of Set 5 | ransang
# Processing Record 26 of Set 5 | presidencia roque saenz pena
# Processing Record 27 of Set 5 | souillac
# Processing Record 28 of Set 5 | ulaangom
# Processing Record 29 of Set 5 | cabo san lucas
# Processing Record 30 of Set 5 | bereda
# Processing Record 31 of Set 5 | bambous virieux
# Processing Record 32 of Set 5 | rocha
# Processing Record 33 of Set 5 | klaksvik
# Processing Record 34 of Set 5 | provideniya
# Processing Record 35 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 5 | ampanihy
# Processing Record 37 of Set 5 | murray bridge
# Processing Record 38 of Set 5 | kholmogory
# Processing Record 39 of Set 5 | bathsheba
# Processing Record 40 of Set 5 | oda
# Processing Record 41 of Set 5 | paita
# Processing Record 42 of Set 5 | coquimbo
# Processing Record 43 of Set 5 | hilo
# Processing Record 44 of Set 5 | tezu
# Processing Record 45 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 46 of Set 5 | doha
# Processing Record 47 of Set 5 | tilichiki
# Processing Record 48 of Set 5 | sobolevo
# Processing Record 49 of Set 5 | varhaug
# Processing Record 50 of Set 5 | dingle
# Processing Record 1 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 6 | san patricio
# Processing Record 3 of Set 6 | lavrentiya
# Processing Record 4 of Set 6 | ozinki
# Processing Record 5 of Set 6 | xiaoshan
# Processing Record 6 of Set 6 | coleraine
# Processing Record 7 of Set 6 | ferme-neuve
# Processing Record 8 of Set 6 | nakhon si thammarat
# Processing Record 9 of Set 6 | durban
# Processing Record 10 of Set 6 | moron
# Processing Record 11 of Set 6 | marienburg
# Processing Record 12 of Set 6 | xining
# Processing Record 13 of Set 6 | carlsbad
# Processing Record 14 of Set 6 | haines junction
# Processing Record 15 of Set 6 | pochutla
# Processing Record 16 of Set 6 | kenora
# Processing Record 17 of Set 6 | haapiti
# Processing Record 18 of Set 6 | karpogory
# Processing Record 19 of Set 6 | ritchie
# Processing Record 20 of Set 6 | namibe
# Processing Record 21 of Set 6 | ati
# Processing Record 22 of Set 6 | whitehorse
# Processing Record 23 of Set 6 | hami
# Processing Record 24 of Set 6 | copiapo
# Processing Record 25 of Set 6 | denpasar
# Processing Record 26 of Set 6 | bahia blanca
# Processing Record 27 of Set 6 | lenger
# Processing Record 28 of Set 6 | santa maria
# Processing Record 29 of Set 6 | barranca
# Processing Record 30 of Set 6 | sault sainte marie
# Processing Record 31 of Set 6 | aklavik
# Processing Record 32 of Set 6 | bossembele
# City not found. Skipping...
# Processing Record 33 of Set 6 | sorland
# Processing Record 34 of Set 6 | qostanay
# Processing Record 35 of Set 6 | tonantins
# Processing Record 36 of Set 6 | vanderhoof
# Processing Record 37 of Set 6 | valparaiso
# Processing Record 38 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 6 | sitka
# Processing Record 41 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 6 | gemunden
# Processing Record 43 of Set 6 | ojinaga
# Processing Record 44 of Set 6 | znamenskoye
# Processing Record 45 of Set 6 | kendari
# Processing Record 46 of Set 6 | bridgend
# Processing Record 47 of Set 6 | yarmouth
# Processing Record 48 of Set 6 | daru
# Processing Record 49 of Set 6 | kaitangata
# Processing Record 50 of Set 6 | mikuni
# Processing Record 1 of Set 7 | kapoeta
# Processing Record 2 of Set 7 | cockburn town
# Processing Record 3 of Set 7 | goderich
# Processing Record 4 of Set 7 | san cristobal
# Processing Record 5 of Set 7 | castro
# Processing Record 6 of Set 7 | great yarmouth
# Processing Record 7 of Set 7 | lahij
# Processing Record 8 of Set 7 | ahuimanu
# Processing Record 9 of Set 7 | grand gaube
# Processing Record 10 of Set 7 | imeni poliny osipenko
# Processing Record 11 of Set 7 | bilgi
# Processing Record 12 of Set 7 | caravelas
# Processing Record 13 of Set 7 | saint george
# Processing Record 14 of Set 7 | cravo norte
# Processing Record 15 of Set 7 | ismailia
# Processing Record 16 of Set 7 | katangli
# Processing Record 17 of Set 7 | saint-augustin
# Processing Record 18 of Set 7 | nelson bay
# Processing Record 19 of Set 7 | guerrero negro
# Processing Record 20 of Set 7 | kodiak
# Processing Record 21 of Set 7 | koulikoro
# Processing Record 22 of Set 7 | gwanda
# Processing Record 23 of Set 7 | firovo
# Processing Record 24 of Set 7 | clyde river
# Processing Record 25 of Set 7 | alta floresta
# Processing Record 26 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 7 | mabaruma
# Processing Record 28 of Set 7 | humaita
# Processing Record 29 of Set 7 | homer
# Processing Record 30 of Set 7 | yaan
# Processing Record 31 of Set 7 | uong bi
# Processing Record 32 of Set 7 | kannur
# Processing Record 33 of Set 7 | portland
# Processing Record 34 of Set 7 | porangatu
# Processing Record 35 of Set 7 | cherkasskoye
# Processing Record 36 of Set 7 | urubicha
# Processing Record 37 of Set 7 | quarai
# Processing Record 38 of Set 7 | crib point
# Processing Record 39 of Set 7 | touros
# Processing Record 40 of Set 7 | puerto baquerizo moreno
# Processing Record 41 of Set 7 | mao
# Processing Record 42 of Set 7 | yatou
# Processing Record 43 of Set 7 | mount gambier
# Processing Record 44 of Set 7 | conde
# Processing Record 45 of Set 7 | korla
# Processing Record 46 of Set 7 | albina
# Processing Record 47 of Set 7 | quatre cocos
# Processing Record 48 of Set 7 | salina
# Processing Record 49 of Set 7 | iqaluit
# Processing Record 50 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 8 | kota kinabalu
# Processing Record 2 of Set 8 | igrim
# Processing Record 3 of Set 8 | laguna
# Processing Record 4 of Set 8 | hofn
# Processing Record 5 of Set 8 | veraval
# Processing Record 6 of Set 8 | itarema
# Processing Record 7 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 8 | kijang
# Processing Record 9 of Set 8 | batagay-alyta
# Processing Record 10 of Set 8 | tulln
# Processing Record 11 of Set 8 | belaya gora
# Processing Record 12 of Set 8 | vila franca do campo
# Processing Record 13 of Set 8 | san jeronimo
# Processing Record 14 of Set 8 | college
# Processing Record 15 of Set 8 | hurricane
# Processing Record 16 of Set 8 | salalah
# Processing Record 17 of Set 8 | kuressaare
# Processing Record 18 of Set 8 | bam
# Processing Record 19 of Set 8 | antofagasta
# Processing Record 20 of Set 8 | dolores
# Processing Record 21 of Set 8 | epe
# Processing Record 22 of Set 8 | nakhon thai
# Processing Record 23 of Set 8 | oranjemund
# Processing Record 24 of Set 8 | ugoofaaru
# Processing Record 25 of Set 8 | ngorongoro
# Processing Record 26 of Set 8 | kieta
# Processing Record 27 of Set 8 | mineiros
# Processing Record 28 of Set 8 | lakhnadon
# Processing Record 29 of Set 8 | togur
# Processing Record 30 of Set 8 | tautira
# Processing Record 31 of Set 8 | kashi
# Processing Record 32 of Set 8 | garissa
# Processing Record 33 of Set 8 | vorukh
# Processing Record 34 of Set 8 | trairi
# Processing Record 35 of Set 8 | longkou
# Processing Record 36 of Set 8 | lorengau
# Processing Record 37 of Set 8 | bastia
# Processing Record 38 of Set 8 | teknaf
# Processing Record 39 of Set 8 | santiago de cuba
# Processing Record 40 of Set 8 | newport
# Processing Record 41 of Set 8 | prieska
# Processing Record 42 of Set 8 | bud
# Processing Record 43 of Set 8 | bintulu
# Processing Record 44 of Set 8 | faya
# Processing Record 45 of Set 8 | zyryanka
# Processing Record 46 of Set 8 | chalus
# Processing Record 47 of Set 8 | kigoma
# Processing Record 48 of Set 8 | kailua
# Processing Record 49 of Set 8 | rancho palos verdes
# Processing Record 50 of Set 8 | araouane
# Processing Record 1 of Set 9 | otjimbingwe
# Processing Record 2 of Set 9 | mahebourg
# Processing Record 3 of Set 9 | ribeira grande
# Processing Record 4 of Set 9 | sioux lookout
# Processing Record 5 of Set 9 | chapais
# Processing Record 6 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 9 | russkaya polyana
# Processing Record 8 of Set 9 | fort nelson
# Processing Record 9 of Set 9 | neiba
# Processing Record 10 of Set 9 | christchurch
# Processing Record 11 of Set 9 | luba
# Processing Record 12 of Set 9 | dabakala
# Processing Record 13 of Set 9 | slatina
# Processing Record 14 of Set 9 | leopold
# Processing Record 15 of Set 9 | nemuro
# Processing Record 16 of Set 9 | bergama
# Processing Record 17 of Set 9 | saldus
# Processing Record 18 of Set 9 | kindu
# Processing Record 19 of Set 9 | turka
# Processing Record 20 of Set 9 | marzuq
# Processing Record 21 of Set 9 | mitsamiouli
# Processing Record 22 of Set 9 | comodoro rivadavia
# Processing Record 23 of Set 9 | santa engracia
# Processing Record 24 of Set 9 | maldonado
# Processing Record 25 of Set 9 | baneh
# Processing Record 26 of Set 9 | umm lajj
# Processing Record 27 of Set 9 | wilmington
# Processing Record 28 of Set 9 | kasempa
# Processing Record 29 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 30 of Set 9 | gaya
# Processing Record 31 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 9 | vanavara
# Processing Record 33 of Set 9 | byron bay
# Processing Record 34 of Set 9 | gold coast
# Processing Record 35 of Set 9 | ostrovnoy
# Processing Record 36 of Set 9 | valle nacional
# Processing Record 37 of Set 9 | bonthe
# Processing Record 38 of Set 9 | burkhala
# City not found. Skipping...
# Processing Record 39 of Set 9 | hope
# Processing Record 40 of Set 9 | petilia policastro
# Processing Record 41 of Set 9 | dali
# Processing Record 42 of Set 9 | yulara
# Processing Record 43 of Set 9 | namie
# Processing Record 44 of Set 9 | constantine
# Processing Record 45 of Set 9 | ambovombe
# Processing Record 46 of Set 9 | ust-ishim
# Processing Record 47 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 48 of Set 9 | cotacachi
# Processing Record 49 of Set 9 | jega
# Processing Record 50 of Set 9 | bahia honda
# Processing Record 1 of Set 10 | buraydah
# Processing Record 2 of Set 10 | vung tau
# Processing Record 3 of Set 10 | sao joao da barra
# Processing Record 4 of Set 10 | luanda
# Processing Record 5 of Set 10 | ialibu
# Processing Record 6 of Set 10 | canavieiras
# Processing Record 7 of Set 10 | sedalia
# Processing Record 8 of Set 10 | havre-saint-pierre
# Processing Record 9 of Set 10 | matara
# Processing Record 10 of Set 10 | victor harbor
# Processing Record 11 of Set 10 | magaria
# Processing Record 12 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 10 | henties bay
# Processing Record 14 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 15 of Set 10 | stavern
# Processing Record 16 of Set 10 | ulaanbaatar
# Processing Record 17 of Set 10 | luganville
# Processing Record 18 of Set 10 | karla
# Processing Record 19 of Set 10 | olafsvik
# Processing Record 20 of Set 10 | senanga
# Processing Record 21 of Set 10 | morant bay
# Processing Record 22 of Set 10 | fukue
# Processing Record 23 of Set 10 | talnakh
# Processing Record 24 of Set 10 | quang ngai
# Processing Record 25 of Set 10 | egvekinot
# Processing Record 26 of Set 10 | port augusta
# Processing Record 27 of Set 10 | anchorage
# Processing Record 28 of Set 10 | mount pleasant
# Processing Record 29 of Set 10 | kollam
# Processing Record 30 of Set 10 | lebedinyy
# Processing Record 31 of Set 10 | asosa
# Processing Record 32 of Set 10 | labuan
# Processing Record 33 of Set 10 | escanaba
# Processing Record 34 of Set 10 | lata
# Processing Record 35 of Set 10 | kuliyapitiya
# Processing Record 36 of Set 10 | lalomanu
# City not found. Skipping...
# Processing Record 37 of Set 10 | mehtar lam
# Processing Record 38 of Set 10 | pietersburg
# Processing Record 39 of Set 10 | promyshlennyy
# Processing Record 40 of Set 10 | bisira
# Processing Record 41 of Set 10 | wad rawah
# Processing Record 42 of Set 10 | saldanha
# Processing Record 43 of Set 10 | semiluki
# Processing Record 44 of Set 10 | kencong
# Processing Record 45 of Set 10 | olot
# Processing Record 46 of Set 10 | vaitape
# Processing Record 47 of Set 10 | turkmenabat
# Processing Record 48 of Set 10 | arlit
# Processing Record 49 of Set 10 | sydney
# Processing Record 50 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 11 | malanje
# Processing Record 2 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 11 | kokkola
# Processing Record 4 of Set 11 | tupik
# Processing Record 5 of Set 11 | mitu
# Processing Record 6 of Set 11 | sao felix do xingu
# Processing Record 7 of Set 11 | oktyabrskiy
# Processing Record 8 of Set 11 | little chute
# Processing Record 9 of Set 11 | fortuna
# Processing Record 10 of Set 11 | nouadhibou
# Processing Record 11 of Set 11 | kununurra
# Processing Record 12 of Set 11 | nacala
# Processing Record 13 of Set 11 | port hawkesbury
# Processing Record 14 of Set 11 | gao
# Processing Record 15 of Set 11 | asau
# Processing Record 16 of Set 11 | rapid city
# Processing Record 17 of Set 11 | glarus
# Processing Record 18 of Set 11 | kawalu
# Processing Record 19 of Set 11 | kade
# Processing Record 20 of Set 11 | shimoda
# Processing Record 21 of Set 11 | winslow
# Processing Record 22 of Set 11 | horki
# Processing Record 23 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 24 of Set 11 | yenagoa
# Processing Record 25 of Set 11 | jibuti
# Processing Record 26 of Set 11 | ancud
# Processing Record 27 of Set 11 | vila
# Processing Record 28 of Set 11 | tilaran
# Processing Record 29 of Set 11 | valdivia
# Processing Record 30 of Set 11 | catia la mar
# Processing Record 31 of Set 11 | tamiahua
# Processing Record 32 of Set 11 | boa vista
# Processing Record 33 of Set 11 | shache
# Processing Record 34 of Set 11 | baghdad
# Processing Record 35 of Set 11 | roebourne
# Processing Record 36 of Set 11 | hirado
# Processing Record 37 of Set 11 | pahrump
# Processing Record 38 of Set 11 | puerto carreno
# Processing Record 39 of Set 11 | port blair
# Processing Record 40 of Set 11 | yantai
# Processing Record 41 of Set 11 | aykhal
# Processing Record 42 of Set 11 | puerto el triunfo
# Processing Record 43 of Set 11 | manitouwadge
# Processing Record 44 of Set 11 | evanston
# Processing Record 45 of Set 11 | la ronge
# Processing Record 46 of Set 11 | puerto leguizamo
# Processing Record 47 of Set 11 | williston
# Processing Record 48 of Set 11 | istisu
# Processing Record 49 of Set 11 | praia
# Processing Record 50 of Set 11 | griffith
# Processing Record 1 of Set 12 | san francisco de macoris
# Processing Record 2 of Set 12 | khokhryaki
# Processing Record 3 of Set 12 | port lincoln
# Processing Record 4 of Set 12 | port-gentil
# Processing Record 5 of Set 12 | mayo
# Processing Record 6 of Set 12 | canton
# Processing Record 7 of Set 12 | turinskaya sloboda
# Processing Record 8 of Set 12 | rongcheng
# Processing Record 9 of Set 12 | olinda
# Processing Record 10 of Set 12 | odweyne
# Processing Record 11 of Set 12 | burica
# City not found. Skipping...
# Processing Record 12 of Set 12 | kampot
# Processing Record 13 of Set 12 | aleksandrovskiy zavod
# Processing Record 14 of Set 12 | orlik
# Processing Record 15 of Set 12 | bom jesus da lapa
# Processing Record 16 of Set 12 | ponta pora
# Processing Record 17 of Set 12 | mount isa
# Processing Record 18 of Set 12 | qixingtai
# Processing Record 19 of Set 12 | tigil
# Processing Record 20 of Set 12 | dongsheng
# Processing Record 21 of Set 12 | progreso
# Processing Record 22 of Set 12 | salina cruz
# Processing Record 23 of Set 12 | koumac
# Processing Record 24 of Set 12 | wenchi
# Processing Record 25 of Set 12 | grinnell
# Processing Record 26 of Set 12 | naze
# Processing Record 27 of Set 12 | lac du bonnet
# Processing Record 28 of Set 12 | yei
# Processing Record 29 of Set 12 | tabou
# Processing Record 30 of Set 12 | kodinsk
# Processing Record 31 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 32 of Set 12 | luoyang
# Processing Record 33 of Set 12 | ketchikan
# Processing Record 34 of Set 12 | fare
# Processing Record 35 of Set 12 | geraldton
# Processing Record 36 of Set 12 | sisimiut
# Processing Record 37 of Set 12 | serebryanyy bor
# Processing Record 38 of Set 12 | zaysan
# Processing Record 39 of Set 12 | amuntai
# Processing Record 40 of Set 12 | tukrah
# Processing Record 41 of Set 12 | tigre
# Processing Record 42 of Set 12 | zeya
# Processing Record 43 of Set 12 | fonte boa
# Processing Record 44 of Set 12 | abalak
# Processing Record 45 of Set 12 | huarmey
# Processing Record 46 of Set 12 | anloga
# Processing Record 47 of Set 12 | vilyuysk
# Processing Record 48 of Set 12 | tual
# Processing Record 49 of Set 12 | saint-joseph
# Processing Record 50 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 13 | andra
# Processing Record 2 of Set 13 | kuching
# Processing Record 3 of Set 13 | nishihara
# Processing Record 4 of Set 13 | hilton head island
# Processing Record 5 of Set 13 | magadan
# Processing Record 6 of Set 13 | maningrida
# Processing Record 7 of Set 13 | shakiso
# Processing Record 8 of Set 13 | gariaband
# Processing Record 9 of Set 13 | yar-sale
# Processing Record 10 of Set 13 | kommunar
# Processing Record 11 of Set 13 | kimbe
# Processing Record 12 of Set 13 | iranshahr
# Processing Record 13 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 13 | saint-paul
# Processing Record 15 of Set 13 | candolim
# Processing Record 16 of Set 13 | vanimo
# Processing Record 17 of Set 13 | linchuan
# City not found. Skipping...
# Processing Record 18 of Set 13 | tarakan
# Processing Record 19 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 20 of Set 13 | yumen
# Processing Record 21 of Set 13 | kamaishi
# Processing Record 22 of Set 13 | lazaro cardenas
# Processing Record 23 of Set 13 | karasjok
# Processing Record 24 of Set 13 | ahipara
# Processing Record 25 of Set 13 | jizan
# Processing Record 26 of Set 13 | les cayes
# Processing Record 27 of Set 13 | skibbereen
# Processing Record 28 of Set 13 | shwebo
# Processing Record 29 of Set 13 | nylstroom
# City not found. Skipping...
# Processing Record 30 of Set 13 | cap malheureux
# Processing Record 31 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 32 of Set 13 | ewa beach
# Processing Record 33 of Set 13 | tommot
# Processing Record 34 of Set 13 | spornoye
# Processing Record 35 of Set 13 | flin flon
# Processing Record 36 of Set 13 | winneba
# Processing Record 37 of Set 13 | vila velha
# Processing Record 38 of Set 13 | poum
# Processing Record 39 of Set 13 | sept-iles
# Processing Record 40 of Set 13 | mortka
# Processing Record 41 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 42 of Set 13 | paamiut
# Processing Record 43 of Set 13 | deputatskiy
# Processing Record 44 of Set 13 | honningsvag
# Processing Record 45 of Set 13 | emba
# Processing Record 46 of Set 13 | okha
# Processing Record 47 of Set 13 | saint-marc
# Processing Record 48 of Set 13 | gangtok
# Processing Record 49 of Set 13 | ouadda
# Processing Record 50 of Set 13 | beloha
# Processing Record 1 of Set 14 | ypsonas
# Processing Record 2 of Set 14 | cam ranh
# Processing Record 3 of Set 14 | innisfail
# Processing Record 4 of Set 14 | gravelbourg
# Processing Record 5 of Set 14 | hereford
# Processing Record 6 of Set 14 | sug-aksy
# City not found. Skipping...
# Processing Record 7 of Set 14 | belmonte
# Processing Record 8 of Set 14 | tokur
# Processing Record 9 of Set 14 | nalut
# Processing Record 10 of Set 14 | gouyave
# Processing Record 11 of Set 14 | calamar
# Processing Record 12 of Set 14 | murgab
# Processing Record 13 of Set 14 | tura
# Processing Record 14 of Set 14 | ajaccio
# Processing Record 15 of Set 14 | cabedelo
# Processing Record 16 of Set 14 | kuala lipis
# Processing Record 17 of Set 14 | niksar
# Processing Record 18 of Set 14 | port moresby
# Processing Record 19 of Set 14 | winnemucca
# Processing Record 20 of Set 14 | viedma
# Processing Record 21 of Set 14 | sao geraldo do araguaia
# Processing Record 22 of Set 14 | doka
# Processing Record 23 of Set 14 | sakakah
# Processing Record 24 of Set 14 | san vicente
# Processing Record 25 of Set 14 | anadyr
# Processing Record 26 of Set 14 | kachug
# Processing Record 27 of Set 14 | matamoros
# Processing Record 28 of Set 14 | san francisco del mar
# Processing Record 29 of Set 14 | bayan
# Processing Record 30 of Set 14 | mount darwin
# Processing Record 31 of Set 14 | bruchsal
# Processing Record 32 of Set 14 | terney
# Processing Record 33 of Set 14 | chontalpa
# Processing Record 34 of Set 14 | nizwa
# Processing Record 35 of Set 14 | prince rupert
# Processing Record 36 of Set 14 | freeport
# Processing Record 37 of Set 14 | nagai
# Processing Record 38 of Set 14 | tankhoy
# Processing Record 39 of Set 14 | arman
# Processing Record 40 of Set 14 | ballina
# Processing Record 41 of Set 14 | tomatlan
# Processing Record 42 of Set 14 | grafton
# Processing Record 43 of Set 14 | katherine
# Processing Record 44 of Set 14 | tobermory
# Processing Record 45 of Set 14 | puli
# Processing Record 46 of Set 14 | mehamn
# Processing Record 47 of Set 14 | abu dhabi
# Processing Record 48 of Set 14 | cholan
# City not found. Skipping...
# Processing Record 49 of Set 14 | floro
# Processing Record 50 of Set 14 | fujin
# Processing Record 1 of Set 15 | nyrob
# Processing Record 2 of Set 15 | lae
# Processing Record 3 of Set 15 | corn island
# Processing Record 4 of Set 15 | manta
# Processing Record 5 of Set 15 | polyarnyy
# Processing Record 6 of Set 15 | kampong thum
# Processing Record 7 of Set 15 | kenai
# Processing Record 8 of Set 15 | west wendover
# Processing Record 9 of Set 15 | hervey bay
# Processing Record 10 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 11 of Set 15 | flinders
# Processing Record 12 of Set 15 | kasungu
# Processing Record 13 of Set 15 | dunda
# Processing Record 14 of Set 15 | horsham
# Processing Record 15 of Set 15 | los llanos de aridane
# Processing Record 16 of Set 15 | general roca
# Processing Record 17 of Set 15 | port lavaca
# Processing Record 18 of Set 15 | sukhobezvodnoye
# Processing Record 19 of Set 15 | sakaiminato
# Processing Record 20 of Set 15 | porterville
# Processing Record 21 of Set 15 | seymchan
# Processing Record 22 of Set 15 | roald
# Processing Record 23 of Set 15 | ilo
# Processing Record 24 of Set 15 | chipiona
# Processing Record 25 of Set 15 | mangrol
# Processing Record 26 of Set 15 | ambon
# Processing Record 27 of Set 15 | banda aceh
# Processing Record 28 of Set 15 | minab
# Processing Record 29 of Set 15 | isangel
# Processing Record 30 of Set 15 | mentok
# City not found. Skipping...
# Processing Record 31 of Set 15 | alihe
# Processing Record 32 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 34 of Set 15 | baijiantan
# Processing Record 35 of Set 15 | caldwell
# Processing Record 36 of Set 15 | karamea
# City not found. Skipping...
# Processing Record 37 of Set 15 | sarangani
# Processing Record 38 of Set 15 | velyka kisnytsya
# City not found. Skipping...
# Processing Record 39 of Set 15 | nyurba
# Processing Record 40 of Set 15 | boueni
# Processing Record 41 of Set 15 | riwaka
# Processing Record 42 of Set 15 | turbat
# Processing Record 43 of Set 15 | inhambane
# Processing Record 44 of Set 15 | garowe
# Processing Record 45 of Set 15 | bardiyah
# Processing Record 46 of Set 15 | mianyang
# Processing Record 47 of Set 15 | akureyri
# Processing Record 48 of Set 15 | hit
# Processing Record 49 of Set 15 | kumta
# Processing Record 50 of Set 15 | latung
# Processing Record 1 of Set 16 | taoudenni
# Processing Record 2 of Set 16 | santa cruz
# Processing Record 3 of Set 16 | upata
# Processing Record 4 of Set 16 | napa
# Processing Record 5 of Set 16 | deloraine
# Processing Record 6 of Set 16 | caucaia
# Processing Record 7 of Set 16 | kungurtug
# Processing Record 8 of Set 16 | komsomolskiy
# Processing Record 9 of Set 16 | dhidhdhoo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len (city_data)
# Out:
# 708

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0        Victoria  22.2855  114.1577     71.65     overcast clouds        91
# 1  Vestmannaeyjar  63.4427  -20.2734     49.19     overcast clouds        93
# 2         Deogarh  21.5333   84.7333     85.37       broken clouds        63
# 3             Leh  34.1667   77.5833     50.81       broken clouds        34
# 4          Barrow  71.2906 -156.7887     21.22           clear sky        86
# 5       Coihaique -45.5752  -72.0662     45.21           clear sky        81
# 6          Albany  42.6001  -73.9662     78.03       broken clouds        77
# 7       Cape Town -33.9258   18.4232     64.35           clear sky        70
# 8          Lompoc  34.6391 -120.4579     71.92       broken clouds        84
# 9          Solano  38.2333 -121.9511     80.33           clear sky        50
#
#    Cloudiness  Wind Speed Country
# 0         100       11.99      HK
# 1         100       12.66      IS
# 2          55        8.10      IN
# 3          51        7.45      IN
# 4           0        5.75      US
# 5           0        5.75      CL
# 6          82        4.25      US
# 7           0        5.01      ZA
# 8          75        8.05      US
# 9           0       23.02      US

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Victoria      HK  22.2855  114.1577     71.65        91
# 1    Vestmannaeyjar      IS  63.4427  -20.2734     49.19        93
# 2           Deogarh      IN  21.5333   84.7333     85.37        63
# 3               Leh      IN  34.1667   77.5833     50.81        34
# 4            Barrow      US  71.2906 -156.7887     21.22        86
# ..              ...     ...      ...       ...       ...       ...
# 703       Deloraine      AU -41.5333  146.6667     50.36        50
# 704         Caucaia      BR  -3.7361  -38.6531     85.95        73
# 705       Kungurtug      RU  50.5994   97.5228     47.16        44
# 706    Komsomolskiy      UZ  40.4272   71.7189     63.32        77
# 707       Dhidhdhoo      MV   6.8833   73.1000     81.48        81
#
#      Cloudiness  Wind Speed Current Description
# 0           100       11.99     overcast clouds
# 1           100       12.66     overcast clouds
# 2            55        8.10       broken clouds
# 3            51        7.45       broken clouds
# 4             0        5.75           clear sky
# ..          ...         ...                 ...
# 703          84        9.15       broken clouds
# 704          20       17.27          few clouds
# 705          18        1.90          few clouds
# 706          72        0.00       broken clouds
# 707         100       24.02     overcast clouds
#
# [708 rows x 9 columns]
